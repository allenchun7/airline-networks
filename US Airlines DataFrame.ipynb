# %%
import pandas as pd

# %%
data = pd.read_csv('airlines.dat.csv')

# %%
df = pd.DataFrame(data)

# %%
df.columns = ['Airline ID', 'Name', 'Alias', 'IATA', 'ICAO', 'Callsign', 'Country', 'Active']

# %%
df
# Out:
#       Airline ID                                          Name  \
# 0              1                                Private flight
# 1              2                                   135 Airways
# 2              3                                 1Time Airline
# 3              4  2 Sqn No 1 Elementary Flying Training School
# 4              5                               213 Flight Unit
# 5              6                 223 Flight Unit State Airline
# 6              7                             224th Flight Unit
# 7              8                                   247 Jet Ltd
# 8              9                                   3D Aviation
# 9             10                                   40-Mile Air
# 10            11                                        4D Air
# 11            12                        611897 Alberta Limited
# 12            13                              Ansett Australia
# 13            14                          Abacus International
# ...

# %%
df_2 = data.Country.str.contains('United States', na = False)
data[df_2]
# Out:
#       Airline ID                              Name                      Alias  \
# 1              2                       135 Airways                         \N
# 8              9                       3D Aviation                         \N
# 9             10                       40-Mile Air                         \N
# 21            22                    Aloha Airlines                         \N
# 22            23                 Alaska Island Air                         \N
# 23            24                 American Airlines                         \N
# 24            25   Aviation Management Corporation                         \N
# 25            26           Atlantis Airlines (USA)                         \N
# 30            31           Astro Air International                         \N
# 34            35                     Allegiant Air                         \N
# 48            49                  Airborne Express                         \N
# ...
