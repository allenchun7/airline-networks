# %%
import pandas as pd

# %%
data = pd.read_csv('airports.dat.csv',header = None)

# %%
df = pd.DataFrame(data)

# %%
df.columns = ['airport id', 'airport name', 'airport city', 'country', 'IATA', 'IACO', 'lat', 'long', 'altitude', 'timezone', 'DST', 'tz database timezone', 'type', 'source']

# %%
df
# Out:
#       airport id                                 airport name  \
# 0              1                               Goroka Airport
# 1              2                               Madang Airport
# 2              3                 Mount Hagen Kagamuga Airport
# 3              4                               Nadzab Airport
# 4              5  Port Moresby Jacksons International Airport
# 5              6                  Wewak International Airport
# 6              7                           Narsarsuaq Airport
# 7              8                      Godthaab / Nuuk Airport
# 8              9                        Kangerlussuaq Airport
# 9             10                               Thule Air Base
# 10            11                             Akureyri Airport
# 11            12                          Egilsstaðir Airport
# 12            13                         Hornafjörður Airport
# 13            14                              Húsavík Airport
# ...

# %%
df_2 = data.country.str.contains('United States', na = False)
data[df_2]
# Out:
#       airport id                              airport name       airport city  \
# 3212        3411                Barter Island LRRS Airport      Barter Island
# 3213        3412                    Wainwright Air Station    Fort Wainwright
# 3214        3413                Cape Lisburne LRRS Airport      Cape Lisburne
# 3215        3414                    Point Lay LRRS Airport          Point Lay
# 3216        3415                Hilo International Airport               Hilo
# 3217        3416                 Orlando Executive Airport            Orlando
# 3218        3417                           Bettles Airport            Bettles
# 3219        3418                             Clear Airport         Clear Mews
# 3220        3419              Indian Mountain LRRS Airport   Indian Mountains
# 3221        3420                        Fort Yukon Airport         Fort Yukon
# 3222        3421                   Sparrevohn LRRS Airport         Sparrevohn
# ...
